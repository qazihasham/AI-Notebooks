# %% [markdown]
# This is the introductory file on basic LLM functionalities

# %%
# %pip install python-dotenv openai
# Out:
# ...
#   Using cached anyio-4.9.0-py3-none-any.whl.metadata (4.7 kB)
# ...
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# ...
#   Using cached jiter-0.10.0-cp311-cp311-win_amd64.whl.metadata (5.3 kB)
# ...
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# ...
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# ...
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# ...
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# ...
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# ...
#    ---------------------------------------- 0.0/734.6 kB ? eta -:--:--
#    -------------- ------------------------- 262.1/734.6 kB ? eta -:--:--
#    ---------------------------------------- 734.6/734.6 kB 3.8 MB/s eta 0:00:00
# Using cached anyio-4.9.0-py3-none-any.whl (100 kB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# ...
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# ...

# %%
from dotenv import load_dotenv
load_dotenv(override=True)
# Out:
# True

# %%
import os
open_ai_key = os.getenv("OPENAI_API_KEY")

if open_ai_key:
    print(f"OpenAI key is set: {open_ai_key[:8]}...")
else:
    print("OpenAI key is not set")
# Out:
# OpenAI key is set: sk-ELsSb...

# %%
from openai import OpenAI
openai_client = OpenAI()

# %%
messages = [{'role': 'system', 'content': 'You are a helpful assistant.'}, {'role': 'user', 'content': 'What is the capital of France?'}]

# %%
response = openai_client.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# The capital of France is Paris.
